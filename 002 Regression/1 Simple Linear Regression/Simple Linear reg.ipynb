# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv("Salary_Data.csv")

# %%
data_frame
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn.model_selection import train_test_split

# %%
x = data_frame.iloc[:, :-1].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y = data_frame.iloc[:, -1].values

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
x_train
# Out:
# array([[10.5],
#        [ 2. ],
#        [ 9.6],
#        [ 8.2],
#        [ 1.5],
#        [ 1.3],
#        [ 4.9],
#        [ 3.7],
#        [ 5.1],
#        [ 2.9],
#        [ 5.9],
#        [ 3.2],
#        [ 9. ],
#        [ 4.5],
#        [ 2.2],
#        [ 7.1],
#        [ 9.5],
#        [ 3.2],
#        [ 4. ],
#        [ 8.7],
#        [ 3.9],
#        [ 1.1]])

# %%
x_train
# Out:
# array([[10.5],
#        [ 2. ],
#        [ 9.6],
#        [ 8.2],
#        [ 1.5],
#        [ 1.3],
#        [ 4.9],
#        [ 3.7],
#        [ 5.1],
#        [ 2.9],
#        [ 5.9],
#        [ 3.2],
#        [ 9. ],
#        [ 4.5],
#        [ 2.2],
#        [ 7.1],
#        [ 9.5],
#        [ 3.2],
#        [ 4. ],
#        [ 8.7],
#        [ 3.9],
#        [ 1.1]])

# %%
y_train
# Out:
# array([105582., 109431.,  37731.,  66029.,  63218.,  39343.,  91738.,
#         57081.,  83088.,  55794., 116969.,  93940.,  57189., 101302.,
#         60150.,  98273.,  56642.,  54445.,  39891., 113812.,  46205.,
#         61111.])

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = regressor.predict(x_test)

# %%
prediction
# Out:
# array([122140.27179529,  75297.20986264,  63118.01376015,  81855.23853321,
#         64054.8749988 ,  53749.40137362,  89350.12844243,  99655.60206762])

# %%
### Plot
plt.scatter(x_train, y_train, color="red")
plt.plot(x_train, regressor.predict(x_train))
plt.title("Salary vs experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(x_test, y_test, color="red")
plt.plot(x_test, prediction)
plt.title("Salary vs experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
